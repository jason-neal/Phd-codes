# %% [markdown]
# ### HD30501 1

# %%
from mingle.utilities.db_utils import SingleSimReader, DBExtractor, df_contour
import matplotlib.pyplot as plt
# %matplotlib inline
from mingle.utilities.param_file import parse_paramfile
# Out:
# /home/jneal/Phd/Codes/companion_simulations/simulators/__init__.py:28: UserWarning: Using the default config.yaml file located at /home/jneal/Phd/Codes/companion_simulations/simulators/../config.yaml.This is likely NOT what you want. Please create a similar 'config.yaml' file in your current working directory.
#   "current working directory.".format(default), UserWarning)
# /home/jneal/Phd/Codes/Repos/Starfish/Starfish/__init__.py:16: UserWarning: Using the default config.yaml file located at /home/jneal/Phd/Codes/Repos/Starfish/Starfish/config.yaml. This is likely NOT what you want. Please create a similar 'config.yaml' file in your current working directory.
#   warnings.warn("Using the default config.yaml file located at {0}. This is likely NOT what you want. Please create a similar 'config.yaml' file in your current working directory.".format(default), UserWarning)

# %%
chi2 = "coadd_chi2"
chi2 = "chi2_1"

# %%
starname = "HD30501"
obsnums = ["1", "2a", "2b", "3"]
rvs = [36.377, 35.120, 35.120, 35.031]
gammas = [22.372, 22.505, 22.507, 22.514]

# %%
# !cat ~/Desktop/Inbox/a/tuned/paper-HD30501/HD30501.sh
# Out:
# #!/usr/bin/env bash
# # Script to analysis HD211847
# obsnums=(1 2a 2b 3)
# for OBS in ${obsnums[@]};
#     do
#         iam_script.py HD30501 $OBS -j 4 -n -m linear -b --suffix _lin_paper_
#
#         bhm_script.py HD30501 $OBS -n -m linear -b --suffix _lin_paper_bh
#     done

# %%
correct = parse_paramfile("/home/jneal/Phd/data/parameter_files/HD30501_params.dat")
correct.update({"teff_1":correct["temp"], "teff_2":correct["comp_temp"],
                "logg_1":correct["logg"], "logg_2":correct["comp_logg"],
                "feh_1":correct["fe_h"], "feh_2":correct["comp_fe_h"]})

print(correct)
print("\nHost temp =", correct["temp"], "K,\tEstimated companion =", correct["comp_temp"], "K")
# Out:
# {'name': 'hd30501', 'companion': 'b', 'mean_val': 23.71, 'k1': 1.7031, 'omega': 70.4, 'eccentricity': 0.741, 'tau': 53851.5, 'period': 2073.6, 'm_star': 0.81, 'msini': 62.3, 'm_true': 89.6, 'temp': 5223.0, 'fe_h': 0.06, 'logg': 4.56, 'source': 'sahlmann et. al. 2011', 'comp_temp': 2498.0, 'comp_logg': 5.3, 'comp_fe_h': 0.06, 'age': '0.8 - 7.0', 'teff_1': 5223.0, 'teff_2': 2498.0, 'logg_1': 4.56, 'logg_2': 5.3, 'feh_1': 0.06, 'feh_2': 0.06}
#
# Host temp = 5223.0 K,	Estimated companion = 2498.0 K

# %% [markdown]
# # Observation 1 - Single Component

# %%
for i, obs in enumerate(obsnums):
    correct.update({"gamma": gammas[i], "rv": rvs[i]-gammas[i]})
    print("########################\nObservation #", obs, "\n########################")
    observation = SingleSimReader(base="/home/jneal/Phd/Analysis/Paper_results/paper-{}".format(starname),
                       name=starname, mode="bhm", suffix="*", obsnum=obs)

    extractor = DBExtractor(observation.get_table())

    df_min = extractor.minimum_value_of(chi2)

    cols = ['gamma', chi2, 'teff_1','logg_1', 'feh_1']

    fixed = {key: df_min[key].values[0] for key in ["logg_1", "feh_1"]}
    print(fixed)
    df = extractor.fixed_extraction(cols, fixed, limit=-1)
    print(df.shape)
    print(df.head())

    df_contour(df, "teff_1", "gamma", chi2, df_min, ["logg_1", "feh_1"], correct=correct, dof=2)
    plt.show()
    print("Min Chi2 result for obs=", obs)
    print(extractor.minimum_value_of(chi2).head())
# Out:
# ########################
# Observation # 1
# ########################
# looking in  /home/jneal/Phd/Analysis/Paper_results/paper-HD30501/HD30501/bhm
# {'logg_1': 4.5, 'feh_1': 0.0}
# (270, 5)
#    gamma         chi2_1  teff_1  logg_1  feh_1
# 0   15.0  202938.708335    4800     4.5    0.0
# 1   15.5  186664.477215    4800     4.5    0.0
# 2   16.0  169418.698210    4800     4.5    0.0
# 3   16.5  154686.371369    4800     4.5    0.0
# 4   17.0  139406.980920    4800     4.5    0.0
# Using chisquare dof= 2
# Min Chi2 result for obs= 1
#    index  teff_1  logg_1  feh_1  gamma  npix_1        chi2_1  arbnorm_1  \
# 0     16    4800     4.5    0.0   22.5     664  67129.060299       1.04
#
#    xcorr_1  npix_2     ...      npix_3         chi2_3  arbnorm_3  xcorr_3  \
# 0     24.3     824     ...         754  151723.839612       1.02     20.8
#
#    npix_4        chi2_4  arbnorm_4  xcorr_4    coadd_chi2  coadd_npix
# 0     615  57954.733763       1.03     55.4  409934.27832        2857
#
# [1 rows x 23 columns]
# ########################
# Observation # 2a
# ########################
# looking in  /home/jneal/Phd/Analysis/Paper_results/paper-HD30501/HD30501/bhm
# {'logg_1': 4.5, 'feh_1': 0.0}
# (270, 5)
#    gamma        chi2_1  teff_1  logg_1  feh_1
# 0   15.0  70885.992374    4800     4.5    0.0
# 1   15.5  67637.551830    4800     4.5    0.0
# 2   16.0  63721.853826    4800     4.5    0.0
# 3   16.5  60727.471911    4800     4.5    0.0
# 4   17.0  57197.062647    4800     4.5    0.0
# Using chisquare dof= 2
# Min Chi2 result for obs= 2a
#    index  teff_1  logg_1  feh_1  gamma  npix_1        chi2_1  arbnorm_1  \
# 0     17    4800     4.5    0.0   23.0     733  30806.502695       1.04
#
#    xcorr_1  npix_2     ...      npix_3        chi2_3  arbnorm_3  xcorr_3  \
# 0     22.7     862     ...         830  50191.071709       1.02     20.8
#
#    npix_4        chi2_4  arbnorm_4  xcorr_4     coadd_chi2  coadd_npix
# 0     687  28385.000828       1.03     50.7  141264.492461        3112
#
# [1 rows x 23 columns]
# ########################
# Observation # 2b
# ########################
# looking in  /home/jneal/Phd/Analysis/Paper_results/paper-HD30501/HD30501/bhm
# {'logg_1': 4.5, 'feh_1': 0.0}
# (270, 5)
#    gamma         chi2_1  teff_1  logg_1  feh_1
# 0   15.0  131750.272202    4800     4.5    0.0
# 1   15.5  126083.469522    4800     4.5    0.0
# 2   16.0  118447.198560    4800     4.5    0.0
# 3   16.5  112841.217596    4800     4.5    0.0
# 4   17.0  105707.842444    4800     4.5    0.0
# Using chisquare dof= 2
# Min Chi2 result for obs= 2b
#    index  teff_1  logg_1  feh_1  gamma  npix_1        chi2_1  arbnorm_1  \
# 0     17    4800     4.5    0.0   23.0     751  55076.002323       1.04
#
#    xcorr_1  npix_2     ...      npix_3         chi2_3  arbnorm_3  xcorr_3  \
# 0     22.8     830     ...         843  104901.134995       1.02     20.7
#
#    npix_4        chi2_4  arbnorm_4  xcorr_4     coadd_chi2  coadd_npix
# 0     593  42253.421894       1.02     54.6  296436.480249        3017
#
# [1 rows x 23 columns]
# ########################
# Observation # 3
# ########################
# looking in  /home/jneal/Phd/Analysis/Paper_results/paper-HD30501/HD30501/bhm
# {'logg_1': 4.5, 'feh_1': 0.0}
# (270, 5)
#    gamma         chi2_1  teff_1  logg_1  feh_1
# 0   15.0  116581.642192    4800     4.5    0.0
# 1   15.5  111367.985463    4800     4.5    0.0
# 2   16.0  104761.845092    4800     4.5    0.0
# 3   16.5   99914.612510    4800     4.5    0.0
# 4   17.0   93748.100325    4800     4.5    0.0
# Using chisquare dof= 2
# Min Chi2 result for obs= 3
#    index  teff_1  logg_1  feh_1  gamma  npix_1       chi2_1  arbnorm_1  \
# 0     17    4800     4.5    0.0   23.0     728  52248.20293       1.04
#
#    xcorr_1  npix_2     ...      npix_3         chi2_3  arbnorm_3  xcorr_3  \
# 0     22.8     865     ...         812  135256.799091       1.02     20.8
#
#    npix_4        chi2_4  arbnorm_4  xcorr_4     coadd_chi2  coadd_npix
# 0     651  65704.828846       1.02    -19.9  343535.792263        3056
#
# [1 rows x 23 columns]

# %% [markdown]
# # Observations - Two components

# %%
for i, obs in enumerate(obsnums):
    correct.update({"gamma": gammas[i], "rv": rvs[i]-gammas[i]})
    print("########################\nObservation #", obs, "\n########################")
    Observation = SingleSimReader(base="/home/jneal/Phd/Analysis/Paper_results/paper-{}".format(starname),
                       name=starname, mode="iam", suffix="*", obsnum=obs)

    extractor = DBExtractor(Observation.get_table())

    df_min = extractor.minimum_value_of("coadd_chi2")

    cols = ['teff_2', 'logg_2', 'feh_2', 'rv', 'gamma',
                chi2, 'teff_1','logg_1', 'feh_1']


    fixed = {key: df_min[key].values[0] for key in ["logg_1", "logg_2", "feh_1", "feh_2"]}
    print(fixed)
    df = extractor.fixed_extraction(cols, fixed, limit=-1)
    print(df.shape)
    df.head()
    
    df_contour(df, "teff_1", "teff_2", chi2, df_min, ["gamma", "rv"], correct=correct, dof=4)
    plt.show()
    df_contour(df, "teff_1", "gamma", chi2, df_min, ["teff_2", "rv"], correct=correct, dof=4)
    plt.show()
    df_contour(df, "teff_2", "rv", chi2, df_min, ["gamma", "teff_1"], correct=correct, dof=4)
    
    print("Min Chi2 result for obs=", obs)
    print(extractor.minimum_value_of(chi2).head())
# Out:
# ########################
# Observation # 1
# ########################
# looking in  /home/jneal/Phd/Analysis/Paper_results/paper-HD30501/HD30501/iam
# {'logg_1': 4.5, 'logg_2': 5.5, 'feh_1': 0.0, 'feh_2': 0.0}
# (43740, 9)
# Using chisquare dof= 4
# Using chisquare dof= 4
# Using chisquare dof= 4
# Min Chi2 result for obs= 1
#    index  teff_2  logg_2  feh_2  alpha_1  npix_1    rv  gamma      chi2_1  \
# 0   4846    3100     5.5    0.0   0.0146     664  16.5   22.5  61588.2105
#
#    arbnorm_1  ...    arbnorm_3  alpha_4  npix_4      chi2_4  arbnorm_4  \
# 0       1.02  ...         1.02   0.0152     615  55427.7208       1.02
#
#    coadd_chi2  coadd_npix  teff_1  logg_1  feh_1
# 0  422879.771        2857  4800.0     4.5    0.0
#
# [1 rows x 27 columns]
# ########################
# Observation # 2a
# ########################
# looking in  /home/jneal/Phd/Analysis/Paper_results/paper-HD30501/HD30501/iam
# {'logg_1': 4.5, 'logg_2': 5.5, 'feh_1': 0.0, 'feh_2': 0.0}
# (43740, 9)
# Using chisquare dof= 4
# Using chisquare dof= 4
# Using chisquare dof= 4
# Min Chi2 result for obs= 2a
#    index  teff_2  logg_2  feh_2  alpha_1  npix_1    rv  gamma      chi2_1  \
# 0   4847    3100     5.5    0.0   0.0146     733  16.5   23.0  27481.6907
#
#    arbnorm_1  ...    arbnorm_3  alpha_4  npix_4      chi2_4  arbnorm_4  \
# 0       1.02  ...         1.02   0.0152     687  28944.7201       1.02
#
#     coadd_chi2  coadd_npix  teff_1  logg_1  feh_1
# 0  142966.0078        3112  4800.0     4.5    0.0
#
# [1 rows x 27 columns]
# ########################
# Observation # 2b
# ########################
# looking in  /home/jneal/Phd/Analysis/Paper_results/paper-HD30501/HD30501/iam
# {'logg_1': 4.5, 'logg_2': 5.5, 'feh_1': 0.0, 'feh_2': 0.0}
# (43740, 9)
# Using chisquare dof= 4
# Using chisquare dof= 4
# Using chisquare dof= 4
# Min Chi2 result for obs= 2b
#    index  teff_2  logg_2  feh_2  alpha_1  npix_1   rv  gamma      chi2_1  \
# 0   4337    3100     5.5    0.0   0.0146     751  8.0   23.0  46912.9775
#
#    arbnorm_1  ...    arbnorm_3  alpha_4  npix_4      chi2_4  arbnorm_4  \
# 0       1.02  ...         1.02   0.0152     593  41277.7158       1.02
#
#     coadd_chi2  coadd_npix  teff_1  logg_1  feh_1
# 0  295172.3536        3017  4800.0     4.5    0.0
#
# [1 rows x 27 columns]
# ########################
# Observation # 3
# ########################
# looking in  /home/jneal/Phd/Analysis/Paper_results/paper-HD30501/HD30501/iam
# {'logg_1': 4.5, 'logg_2': 5.5, 'feh_1': 0.0, 'feh_2': 0.0}
# (43740, 9)
# Using chisquare dof= 4
# Using chisquare dof= 4
# Using chisquare dof= 4
# Min Chi2 result for obs= 3
#    index  teff_2  logg_2  feh_2  alpha_1  npix_1   rv  gamma      chi2_1  \
# 0   4337    3100     5.5    0.0   0.0146     728  8.0   23.0  45164.9137
#
#    arbnorm_1  ...    arbnorm_3  alpha_4  npix_4      chi2_4  arbnorm_4  \
# 0       1.02  ...         1.02   0.0152     651  66384.4189       1.01
#
#     coadd_chi2  coadd_npix  teff_1  logg_1  feh_1
# 0  342030.6875        3056  4800.0     4.5    0.0
#
# [1 rows x 27 columns]

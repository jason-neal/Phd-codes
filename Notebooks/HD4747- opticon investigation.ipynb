# %% [markdown]
# # Investigaion for HD4747
# Experimenting for OPTICON proposal Spetember 2016

# %%
from __future__ import division, print_function
import math
import numpy as np
import sys 
sys.path.append('C:/Users/Jason/Documents/PhD/Codes/equanimous-octo-tribble')
import flux_ratio
import numpy as np
import matplotlib.pyplot as plt
# Some constants
SolMassinMj = 1047.56            # MJjupiter  (1 M_sun = 1047 M_Jupiter)
# %matplotlib inline

# %% [markdown]
# Calculating the visual aboslute magnitude of HD30501 using the parallax and the visual apparent magnitude

# %%
# Using my Code
#k band flux ratio = 11809 # grrrrh!! for a mass of 60Mj'
# ratio of  2000 for a mass of 72MJ

# %% [markdown]
# # What do the absorbtion look like
# The GAINO instrument has a wavelenght range of .9 2.45 micron so covers the wavelength range we already have.
#
#
# I obtain a tapas spectrum at the expected evelvation (30 degrees) at the TNG telescope from october 2015. (The best time for the orbit is october 2017)

# %%
Wavelength, Telluric = np.loadtxt("C:/Users/Jason/Documents/PhD/data/tapas_tng_30deg_october.ipac", skiprows=28, unpack=True)
Wavelength2, Telluric2 = np.loadtxt("C:/Users/Jason/Documents/PhD/data/tapas_tng_60deg_october.ipac", skiprows=28, unpack=True)

# %%
plt.plot(Wavelength, Telluric)
plt.plot(Wavelength2, Telluric2)
plt.xlim([2100, 2150])
plt.ylim([.8, 1])
plt.show()
